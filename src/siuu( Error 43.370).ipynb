# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns

from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_squared_error as mse

from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn.ensemble import GradientBoostingRegressor as GBR
from xgboost import XGBRegressor as XGBR
from catboost import CatBoostRegressor as CTR
from lightgbm import LGBMRegressor as LGBMR

from xgboost import XGBRFRegressor as XGBRF
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.neighbors import KNeighborsRegressor as KNR
from sklearn.linear_model import LogisticRegression as LogReg

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
salaries= pd.read_csv('../data/salaries_data.csv')

test = pd.read_csv('../data/testeo.csv')

# %%
#Borramos columnas que no hace falta
test.drop('salary', inplace=True, axis=1)
#test.drop('salary_currency', inplace=True, axis=1)

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
def diction(col):
    lista = list(set(list(salaries[col].unique()) + list(test[col].unique())))
    nums =[i for i in range(len(lista))]
    print({(lista[i]): (nums[i]) for i in range(len(lista))})
    return {(lista[i]): (nums[i]) for i in range(len(lista))}

dictio_experience_level = diction('experience_level')
dictio_employment_type = diction('employment_type')
dictio_job_title = diction('job_title')
dictio_employee_residence = diction('employee_residence')
dictio_company_location = diction('company_location')
dictio_company_size = diction('company_size')
dictio_salary_currency = diction('salary_currency')
# Out:
# {'EX': 0, 'EN': 1, 'SE': 2, 'MI': 3}
# {'FT': 0, 'CT': 1, 'PT': 2, 'FL': 3}
# {'Machine Learning Manager': 0, 'Machine Learning Developer': 1, 'Data Architect': 2, 'BI Data Analyst': 3, 'Analytics Engineer': 4, 'Data Analytics Manager': 5, 'Cloud Data Engineer': 6, 'Data Specialist': 7, 'Business Data Analyst': 8, 'Research Scientist': 9, 'Lead Data Analyst': 10, 'ETL Developer': 11, 'Big Data Architect': 12, 'Data Engineering Manager': 13, 'Applied Machine Learning Scientist': 14, 'NLP Engineer': 15, 'Data Analytics Engineer': 16, 'Big Data Engineer': 17, 'Director of Data Engineering': 18, 'Data Analytics Lead': 19, 'Data Engineer': 20, 'Principal Data Analyst': 21, 'Computer Vision Software Engineer': 22, 'Data Scientist': 23, 'Finance Data Analyst': 24, 'Director of Data Science': 25, 'Machine Learning Engineer': 26, 'Machine Learning Scientist': 27, 'Head of Machine Learning': 28, 'Product Data Analyst': 29, 'Applied Data Scientist': 30, 'Marketing Data Analyst': 31, 'Data Science Manager': 32, 'Lead Data Engineer': 33, 'Machine Learning Infrastructure Engineer': 34, 'Lead Machine Learning Engineer': 35, 'Head of Data': 36, 'Financial Data Analyst': 37, 'Principal Data Engineer': 38, 'Head of Data Science': 39, 'AI Scientist': 40, 'Principal Data Scientist': 41, 'ML Engineer': 42, 'Computer Vision Engineer': 43, 'Data Science Consultant': 44, 'Staff Data Scientist': 45, 'Data Science Engineer': 46, 'Lead Data Scientist': 47, '3D Computer Vision Researcher': 48, 'Data Analyst': 49}
# {'PK': 0, 'EE': 1, 'DK': 2, 'KE': 3, 'SG': 4, 'IN': 5, 'DE': 6, 'CN': 7, 'FR': 8, 'HN': 9, 'UA': 10, 'AU': 11, 'AE': 12, 'NL': 13, 'IT': 14, 'MT': 15, 'VN': 16, 'RS': 17, 'PH': 18, 'GB': 19, 'CZ': 20, 'SI': 21, 'CA': 22, 'CO': 23, 'AR': 24, 'JE': 25, 'CH': 26, 'HR': 27, 'TN': 28, 'PR': 29, 'HK': 30, 'BR': 31, 'RO': 32, 'MY': 33, 'NG': 34, 'RU': 35, 'ES': 36, 'MX': 37, 'GR': 38, 'PT': 39, 'IQ': 40, 'LU': 41, 'BO': 42, 'BE': 43, 'DZ': 44, 'IR': 45, 'US': 46, 'JP': 47, 'CL': 48, 'BG': 49, 'MD': 50, 'IE': 51, 'NZ': 52, 'TR': 53, 'AT': 54, 'HU': 55, 'PL': 56}
# {'PK': 0, 'DK': 1, 'EE': 2, 'KE': 3, 'SG': 4, 'IN': 5, 'DE': 6, 'CN': 7, 'FR': 8, 'HN': 9, 'UA': 10, 'AU': 11, 'AE': 12, 'NL': 13, 'MT': 14, 'IT': 15, 'VN': 16, 'GB': 17, 'CZ': 18, 'SI': 19, 'CA': 20, 'CO': 21, 'HR': 22, 'CH': 23, 'BR': 24, 'MY': 25, 'RO': 26, 'NG': 27, 'RU': 28, 'ES': 29, 'AS': 30, 'GR': 31, 'MX': 32, 'PT': 33, 'LU': 34, 'IQ': 35, 'BE': 36, 'DZ': 37, 'IR': 38, 'US': 39, 'JP': 40, 'CL': 41, 'IL': 42, 'MD': 43, 'IE': 44, 'NZ': 45, 'TR': 46, 'AT': 47, 'HU': 48, 'PL': 49}
# {'M': 0, 'L': 1, 'S': 2}
# {'INR': 0, 'CLP': 1, 'MXN': 2, 'AUD': 3, 'CHF': 4, 'EUR': 5, 'CNY': 6, 'GBP': 7, 'BRL': 8, 'USD': 9, 'CAD': 10, 'PLN': 11, 'JPY': 12, 'SGD': 13, 'TRY': 14, 'DKK': 15, 'HUF': 16}

# %%
salaries_copy_1 = salaries.copy(deep=True)
salaries_copy_1.head()

salaries_copy_1.drop(['salary'], inplace=True,axis=1)
print(salaries_copy_1.head())

test_copy_1 = test.copy(deep=True)
print(test_copy_1.head())
# Out:
#    work_year experience_level employment_type        job_title  \
# 0       2022               SE              FT    Data Engineer
# 1       2022               SE              FT    Data Engineer
# 2       2021               MI              FT  BI Data Analyst
# 3       2021               MI              CT      ML Engineer
# 4       2021               MI              FT    Data Engineer
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   salary_currency employee_residence  remote_ratio company_location  \
# 0             USD                 JP             0               JP
# 1             USD                 US           100               US
# 2             USD                 US           100               US
# 3             CNY                 CN             0               CN
# 4             INR                 IN           100               IN
#
#   company_size
# 0            S
# 1            L
# 2            L
# 3            M
# 4            L

# %%
test_copy_1.shape, salaries_copy_1.shape
# Out:
# ((107, 9), (500, 10))

# %%
test_copy_1['y'] = -1
test_copy_1.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   salary_currency employee_residence  remote_ratio company_location  \
# 0             USD                 JP             0               JP
# 1             USD                 US           100               US
# 2             USD                 US           100               US
# 3             CNY                 CN             0               CN
# 4             INR                 IN           100               IN
#
#   company_size  y
# 0            S -1
# 1            L -1
# 2            L -1
# 3            M -1
# 4            L -1

# %%
test_copy_1.shape, salaries_copy_1.shape
# Out:
# ((107, 10), (500, 10))

# %%
todo = pd.concat([test_copy_1, salaries_copy_1])

# %%
todo.job_title = todo.job_title.apply(lambda x: dictio_job_title[x])
todo.employment_type = todo.employment_type.apply(lambda x: dictio_employment_type[x])
todo.employee_residence = todo.employee_residence.apply(lambda x: dictio_employee_residence[x])
todo.experience_level = todo.experience_level.apply(lambda x: dictio_experience_level[x])
todo.company_size = todo.company_size.apply(lambda x: dictio_company_size[x])
todo.company_location = todo.company_location.apply(lambda x: dictio_company_location[x])
todo.salary_currency = todo.salary_currency.apply(lambda x: dictio_salary_currency[x])
todo.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2020                 2                0         27                9
# 1       2020                 3                0         10                9
# 2       2020                 3                0         49                9
# 3       2020                 3                0         26                6
# 4       2020                 3                0         29                0
#
#    employee_residence  remote_ratio  company_location  company_size    y  \
# 0                  47             0                40             2 -1.0
# 1                  46           100                39             1 -1.0
# 2                  46           100                39             1 -1.0
# 3                   7             0                 7             0 -1.0
# 4                   5           100                 5             1 -1.0
#
#    salary_in_usd
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
ok = todo.loc[todo['y'] == -1]
ok.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2020                 2                0         27                9
# 1       2020                 3                0         10                9
# 2       2020                 3                0         49                9
# 3       2020                 3                0         26                6
# 4       2020                 3                0         29                0
#
#    employee_residence  remote_ratio  company_location  company_size    y  \
# 0                  47             0                40             2 -1.0
# 1                  46           100                39             1 -1.0
# 2                  46           100                39             1 -1.0
# 3                   7             0                 7             0 -1.0
# 4                   5           100                 5             1 -1.0
#
#    salary_in_usd
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
ok.shape
# Out:
# (107, 11)

# %%
ok_s = todo.loc[todo['y'] != -1]
ok_s.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2022                 2                0         20                9
# 1       2022                 2                0         20                9
# 2       2021                 3                0          3                9
# 3       2021                 3                1         42                9
# 4       2021                 3                0         20                5
#
#    employee_residence  remote_ratio  company_location  company_size   y  \
# 0                  46           100                39             0 NaN
# 1                  46           100                39             0 NaN
# 2                  46           100                39             0 NaN
# 3                  46           100                39             1 NaN
# 4                  32             0                39             1 NaN
#
#    salary_in_usd
# 0       140250.0
# 1       135000.0
# 2       100000.0
# 3       270000.0
# 4        26005.0

# %%
ok_s.shape
# Out:
# (500, 11)

# %%
ok_s.drop('y', axis=1, inplace=True)
ok.drop('salary_in_usd', axis=1, inplace=True)
ok.drop('y', axis=1, inplace=True)

# %% [markdown]
# ## Modelos

# %%
X = ok_s.drop('salary_in_usd', axis = 1)
y = ok_s.salary_in_usd

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size=0.99, test_size=0.01, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((495, 9), (5, 9), (495,), (5,))

# %%
#Inicializamos modelos
rfr=RFR()
etr=ETR()
gbr=GBR()
xgbr=XGBR()
ctr=CTR()
dtr=DTR()
lgbmr=LGBMR()
xgbrf = XGBRF()
linreg = LinReg()
knr = KNR()
logreg = LogReg()

#Entrenamientos
rfr.fit(X_train, y_train)
etr.fit(X_train, y_train)
gbr.fit(X_train, y_train)
xgbr.fit(X_train, y_train)
ctr.fit(X_train, y_train, verbose=0)
dtr.fit(X_train, y_train)
lgbmr.fit(X_train, y_train)
xgbrf.fit(X_train, y_train)
linreg.fit(X_train, y_train)
knr.fit(X_train, y_train)
logreg.fit(X_train, y_train)

#Predicciones
y_pred_rfr = rfr.predict(X_test)
y_pred_etr = etr.predict(X_test)
y_pred_gbr = gbr.predict(X_test)
y_pred_xgbr = xgbr.predict(X_test)
y_pred_ctr = ctr.predict(X_test)
y_pred_dtr = dtr.predict(X_test)
y_pred_lgbmr = lgbmr.predict(X_test)
y_pred_xgbrf = xgbrf.predict(X_test)
y_pred_linreg = linreg.predict(X_test)
y_pred_knr = knr.predict(X_test)
y_pred_logreg = logreg.predict(X_test)

#Calculo de error
print(mse(y_test, y_pred_rfr, squared=False), mse(y_test, y_pred_etr, squared=False), mse(y_test, y_pred_gbr, squared=False), 
mse(y_test, y_pred_xgbr, squared=False), mse(y_test, y_pred_ctr, squared=False), mse(y_test, y_pred_dtr, squared=False),
mse(y_test, y_pred_lgbmr, squared=False), mse(y_test, y_pred_xgbrf, squared=False), mse(y_test, y_pred_linreg, squared=False),
mse(y_test, y_pred_knr, squared=False), mse(y_test, y_pred_logreg, squared=False))
# Out:
# 29436.485469502473 31107.05042561317 33480.51147098285 29559.56859985629 29130.896412837414 31107.05042561317 29772.334968091258 36992.741354246085 31186.790550923113 23681.11686758038 33381.519438156196

# %% [markdown]
# ### Mejor Modelo: KNeighborsRegressor

# %%
knr.fit(X_train, y_train)

y_pred_knr = knr.predict(ok)
y_pred_knr[:10]

len(y_pred_knr)
# Out:
# 107

# %% [markdown]
# ## Exportar

# %%
res = pd.read_csv('../data/muestra.csv')
res.salary_in_usd = y_pred_knr
res.head()
# Out:
#    id  salary_in_usd
# 0   0       192459.2
# 1   1       146400.0
# 2   2       121800.0
# 3   3        72436.8
# 4   4        35203.8

# %%
res.to_csv('../data/resultado_knr_contodo_0.99.csv', index = False)
