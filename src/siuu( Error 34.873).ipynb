# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns

from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_squared_error as mse

from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn.ensemble import GradientBoostingRegressor as GBR
from xgboost import XGBRegressor as XGBR
from catboost import CatBoostRegressor as CTR
from lightgbm import LGBMRegressor as LGBMR

from xgboost import XGBRFRegressor as XGBRF
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.neighbors import KNeighborsRegressor as KNR
from sklearn.linear_model import LogisticRegression as LogReg

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
salaries= pd.read_csv('../data/salaries_data.csv')

test = pd.read_csv('../data/testeo.csv')

# %%
#Borramos columnas que no hace falta
test.drop('salary', inplace=True, axis=1)
#test.drop('salary_currency', inplace=True, axis=1)

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
def diction(col):
    lista = list(set(list(salaries[col].unique()) + list(test[col].unique())))
    nums =[i for i in range(len(lista))]
    print({(lista[i]): (nums[i]) for i in range(len(lista))})
    return {(lista[i]): (nums[i]) for i in range(len(lista))}

dictio_experience_level = diction('experience_level')
dictio_employment_type = diction('employment_type')
dictio_job_title = diction('job_title')
dictio_employee_residence = diction('employee_residence')
dictio_company_location = diction('company_location')
dictio_company_size = diction('company_size')
dictio_salary_currency = diction('salary_currency')
# Out:
# {'EX': 0, 'MI': 1, 'SE': 2, 'EN': 3}
# {'FT': 0, 'CT': 1, 'FL': 2, 'PT': 3}
# {'Data Engineering Manager': 0, 'Research Scientist': 1, 'Director of Data Science': 2, 'Head of Data': 3, 'Data Science Consultant': 4, 'Data Specialist': 5, 'Lead Data Analyst': 6, '3D Computer Vision Researcher': 7, 'Machine Learning Scientist': 8, 'ETL Developer': 9, 'Head of Machine Learning': 10, 'BI Data Analyst': 11, 'ML Engineer': 12, 'Head of Data Science': 13, 'Product Data Analyst': 14, 'Director of Data Engineering': 15, 'Cloud Data Engineer': 16, 'Principal Data Analyst': 17, 'Staff Data Scientist': 18, 'Computer Vision Engineer': 19, 'Data Science Engineer': 20, 'Data Architect': 21, 'Data Engineer': 22, 'Big Data Architect': 23, 'Analytics Engineer': 24, 'Data Analytics Lead': 25, 'Data Analytics Manager': 26, 'Finance Data Analyst': 27, 'Principal Data Scientist': 28, 'Machine Learning Manager': 29, 'Lead Data Scientist': 30, 'Lead Data Engineer': 31, 'Machine Learning Infrastructure Engineer': 32, 'Business Data Analyst': 33, 'Principal Data Engineer': 34, 'Machine Learning Engineer': 35, 'AI Scientist': 36, 'Marketing Data Analyst': 37, 'Data Science Manager': 38, 'Machine Learning Developer': 39, 'NLP Engineer': 40, 'Data Scientist': 41, 'Big Data Engineer': 42, 'Applied Data Scientist': 43, 'Applied Machine Learning Scientist': 44, 'Data Analytics Engineer': 45, 'Data Analyst': 46, 'Financial Data Analyst': 47, 'Lead Machine Learning Engineer': 48, 'Computer Vision Software Engineer': 49}
# {'CA': 0, 'US': 1, 'IN': 2, 'AU': 3, 'PL': 4, 'CH': 5, 'IQ': 6, 'EE': 7, 'PH': 8, 'SG': 9, 'RO': 10, 'RS': 11, 'BO': 12, 'UA': 13, 'GB': 14, 'NG': 15, 'AT': 16, 'MX': 17, 'CL': 18, 'AE': 19, 'JP': 20, 'DZ': 21, 'MY': 22, 'HU': 23, 'VN': 24, 'KE': 25, 'LU': 26, 'HR': 27, 'PT': 28, 'DE': 29, 'HN': 30, 'DK': 31, 'BE': 32, 'IR': 33, 'CZ': 34, 'NZ': 35, 'BR': 36, 'FR': 37, 'PK': 38, 'RU': 39, 'CN': 40, 'GR': 41, 'ES': 42, 'TN': 43, 'MT': 44, 'TR': 45, 'AR': 46, 'IT': 47, 'HK': 48, 'PR': 49, 'CO': 50, 'JE': 51, 'SI': 52, 'IE': 53, 'NL': 54, 'MD': 55, 'BG': 56}
# {'CA': 0, 'US': 1, 'IN': 2, 'AU': 3, 'PL': 4, 'CH': 5, 'IQ': 6, 'EE': 7, 'SG': 8, 'RO': 9, 'UA': 10, 'GB': 11, 'NG': 12, 'AT': 13, 'MX': 14, 'CL': 15, 'AE': 16, 'JP': 17, 'DZ': 18, 'MY': 19, 'HU': 20, 'LU': 21, 'VN': 22, 'KE': 23, 'HR': 24, 'PT': 25, 'DE': 26, 'HN': 27, 'DK': 28, 'BE': 29, 'AS': 30, 'IR': 31, 'CZ': 32, 'NZ': 33, 'BR': 34, 'IL': 35, 'FR': 36, 'PK': 37, 'RU': 38, 'CN': 39, 'GR': 40, 'ES': 41, 'MT': 42, 'TR': 43, 'IT': 44, 'CO': 45, 'SI': 46, 'IE': 47, 'NL': 48, 'MD': 49}
# {'S': 0, 'L': 1, 'M': 2}
# {'SGD': 0, 'GBP': 1, 'TRY': 2, 'EUR': 3, 'CHF': 4, 'BRL': 5, 'MXN': 6, 'JPY': 7, 'INR': 8, 'CLP': 9, 'DKK': 10, 'AUD': 11, 'PLN': 12, 'USD': 13, 'CAD': 14, 'HUF': 15, 'CNY': 16}

# %%
salaries_copy_1 = salaries.copy(deep=True)
salaries_copy_1.head()

salaries_copy_1.drop(['salary'], inplace=True,axis=1)
print(salaries_copy_1.head())

test_copy_1 = test.copy(deep=True)
print(test_copy_1.head())
# Out:
#    work_year experience_level employment_type        job_title  \
# 0       2022               SE              FT    Data Engineer
# 1       2022               SE              FT    Data Engineer
# 2       2021               MI              FT  BI Data Analyst
# 3       2021               MI              CT      ML Engineer
# 4       2021               MI              FT    Data Engineer
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   salary_currency employee_residence  remote_ratio company_location  \
# 0             USD                 JP             0               JP
# 1             USD                 US           100               US
# 2             USD                 US           100               US
# 3             CNY                 CN             0               CN
# 4             INR                 IN           100               IN
#
#   company_size
# 0            S
# 1            L
# 2            L
# 3            M
# 4            L

# %%
test_copy_1.shape, salaries_copy_1.shape
# Out:
# ((107, 9), (500, 10))

# %%
test_copy_1['y'] = -1
test_copy_1.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   salary_currency employee_residence  remote_ratio company_location  \
# 0             USD                 JP             0               JP
# 1             USD                 US           100               US
# 2             USD                 US           100               US
# 3             CNY                 CN             0               CN
# 4             INR                 IN           100               IN
#
#   company_size  y
# 0            S -1
# 1            L -1
# 2            L -1
# 3            M -1
# 4            L -1

# %%
test_copy_1.shape, salaries_copy_1.shape
# Out:
# ((107, 10), (500, 10))

# %%
todo = pd.concat([test_copy_1, salaries_copy_1])

# %%
todo.job_title = todo.job_title.apply(lambda x: dictio_job_title[x])
todo.employment_type = todo.employment_type.apply(lambda x: dictio_employment_type[x])
todo.employee_residence = todo.employee_residence.apply(lambda x: dictio_employee_residence[x])
todo.experience_level = todo.experience_level.apply(lambda x: dictio_experience_level[x])
todo.company_size = todo.company_size.apply(lambda x: dictio_company_size[x])
todo.company_location = todo.company_location.apply(lambda x: dictio_company_location[x])
todo.salary_currency = todo.salary_currency.apply(lambda x: dictio_salary_currency[x])
todo.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2020                 2                0          8               13
# 1       2020                 1                0          6               13
# 2       2020                 1                0         46               13
# 3       2020                 1                0         35               16
# 4       2020                 1                0         14                8
#
#    employee_residence  remote_ratio  company_location  company_size    y  \
# 0                  20             0                17             0 -1.0
# 1                   1           100                 1             1 -1.0
# 2                   1           100                 1             1 -1.0
# 3                  40             0                39             2 -1.0
# 4                   2           100                 2             1 -1.0
#
#    salary_in_usd
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
ok = todo.loc[todo['y'] == -1]
ok.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2020                 2                0          8               13
# 1       2020                 1                0          6               13
# 2       2020                 1                0         46               13
# 3       2020                 1                0         35               16
# 4       2020                 1                0         14                8
#
#    employee_residence  remote_ratio  company_location  company_size    y  \
# 0                  20             0                17             0 -1.0
# 1                   1           100                 1             1 -1.0
# 2                   1           100                 1             1 -1.0
# 3                  40             0                39             2 -1.0
# 4                   2           100                 2             1 -1.0
#
#    salary_in_usd
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
ok.shape
# Out:
# (107, 11)

# %%
ok_s = todo.loc[todo['y'] != -1]
ok_s.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_currency  \
# 0       2022                 2                0         22               13
# 1       2022                 2                0         22               13
# 2       2021                 1                0         11               13
# 3       2021                 1                1         12               13
# 4       2021                 1                0         22                3
#
#    employee_residence  remote_ratio  company_location  company_size   y  \
# 0                   1           100                 1             2 NaN
# 1                   1           100                 1             2 NaN
# 2                   1           100                 1             2 NaN
# 3                   1           100                 1             1 NaN
# 4                  10             0                 1             1 NaN
#
#    salary_in_usd
# 0       140250.0
# 1       135000.0
# 2       100000.0
# 3       270000.0
# 4        26005.0

# %%
ok_s.shape
# Out:
# (500, 11)

# %%
ok_s.drop('y', axis=1, inplace=True)
ok.drop('salary_in_usd', axis=1, inplace=True)
ok.drop('y', axis=1, inplace=True)

# %% [markdown]
# ## Modelos

# %%
X = ok_s.drop('salary_in_usd', axis = 1)
y = ok_s.salary_in_usd

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 9), (100, 9), (400,), (100,))

# %%
#Inicializamos modelos
rfr=RFR()
etr=ETR()
gbr=GBR()
xgbr=XGBR()
ctr=CTR()
dtr=DTR()
lgbmr=LGBMR()
xgbrf = XGBRF()
linreg = LinReg()
knr = KNR()
logreg = LogReg()

#Entrenamientos
rfr.fit(X_train, y_train)
etr.fit(X_train, y_train)
gbr.fit(X_train, y_train)
xgbr.fit(X_train, y_train)
ctr.fit(X_train, y_train, verbose=0)
dtr.fit(X_train, y_train)
lgbmr.fit(X_train, y_train)
xgbrf.fit(X_train, y_train)
linreg.fit(X_train, y_train)
knr.fit(X_train, y_train)
logreg.fit(X_train, y_train)

#Predicciones
y_pred_rfr = rfr.predict(X_test)
y_pred_etr = etr.predict(X_test)
y_pred_gbr = gbr.predict(X_test)
y_pred_xgbr = xgbr.predict(X_test)
y_pred_ctr = ctr.predict(X_test)
y_pred_dtr = dtr.predict(X_test)
y_pred_lgbmr = lgbmr.predict(X_test)
y_pred_xgbrf = xgbrf.predict(X_test)
y_pred_linreg = linreg.predict(X_test)
y_pred_knr = knr.predict(X_test)
y_pred_logreg = logreg.predict(X_test)

#Calculo de error
print(mse(y_test, y_pred_rfr, squared=False), mse(y_test, y_pred_etr, squared=False), mse(y_test, y_pred_gbr, squared=False), 
mse(y_test, y_pred_xgbr, squared=False), mse(y_test, y_pred_ctr, squared=False), mse(y_test, y_pred_dtr, squared=False),
mse(y_test, y_pred_lgbmr, squared=False), mse(y_test, y_pred_xgbrf, squared=False), mse(y_test, y_pred_linreg, squared=False),
mse(y_test, y_pred_knr, squared=False), mse(y_test, y_pred_logreg, squared=False))
# Out:
# 41801.946382330614 46776.344785377696 39523.69101545984 42901.568720809584 40173.316025949534 52761.15033812998 45867.877397223805 40093.61249443867 50425.72278445313 50465.73730218949 56886.07580146481

# %% [markdown]
# ### Mejor Modelo: GradientBoostingRegressor

# %%
gbr.fit(X_train, y_train)

y_pred_gbr = gbr.predict(ok)
y_pred_gbr[:10]

len(y_pred_gbr)
# Out:
# 107

# %% [markdown]
# ## Exportar

# %%
res = pd.read_csv('../data/muestra.csv')
res.salary_in_usd = y_pred_gbr
res.head()
# Out:
#    id  salary_in_usd
# 0   0   93950.364969
# 1   1  169542.043032
# 2   2  120477.291857
# 3   3   40750.320263
# 4   4   65303.939385

# %%
res.to_csv('../data/resultado_gbr_contodo_curren2.csv', index = False)
